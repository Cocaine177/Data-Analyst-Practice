# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
x1 = np.array([9, 5, 10, 17, 8])
y1 = np.array([3, 8, 1, 7, 6])

x2 = np.array([13, 18, 11, 7, 5])
y2 = np.array([1, 2, 9, 5, 7])

# Font styling
font1 = {'family': 'Times New Roman', 'color': 'blue', 'size': 20}
font2 = {'family': 'Times New Roman', 'color': 'darkred', 'size': 15}
x`
# Title and axis labels
plt.title("Food Vs Price Competition", fontdict=font2,loc='center')
plt.xlabel("Food", fontdict=font1)
plt.ylabel("Price", fontdict=font2)

# Plotting all lines with correct x-y pairing and custom styles
plt.plot(x1,marker='o', ms=5, mec='r', mfc='y', ls=':', color='red', linewidth=1, label='Group 1')
plt.plot(x2,marker='o', ms=5, mec='g', mfc='b', ls='--', color='green', linewidth=1, label='Group 2')
plt.plot(y1,marker='o', ms=5, mec='b', mfc='g', ls='-.', color='blue', linewidth=1, label='Group 3')
plt.plot(y2,marker='o', ms=5, mec='y', mfc='r', ls='-', color='pink', linewidth=1, label='Group 4')

# Add legend
plt.legend()
plt.grid(color='blue',linestyle=':',linewidth='0.5')



# Show plot
plt.show()
